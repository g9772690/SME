# %% [markdown]
# # *  파이썬 기초
# *   파이썬 (Python) : 1991년 귀도 반 로섬 (Guido van Rossum)이 개발하였으며, 초보자가 쉽게 배울 수 있는 프로그래밍 언어
# *   파이썬의 장점
#   *   비전공자도 쉽게 배울 수 있음
#   *   다양한 분야에서 활용할 수 있음
#   *   대부분의 운영체제에서 동일하게 사용됨
# *   파이썬의 단점
#   *   C언어에 비해 일반적으로 10~350배 느림
#   *   최근에는 컴퓨터 성능이 좋아져 연산이 많이 필요한 프로그램이 아니라면 차이 크게 느낄 수 없음

# %% [markdown]
# *   주요 용어
#   *   이진 숫자 (binary digit) : 0과 1로 이루어진 컴퓨터의 언어
#   *   이진 코드 (binary code) : 이진 숫자로 이루어진 코드
#   *   프로그래밍 언어 (programming language) : 사람이 이해하기 쉬운 언어로 프로그램을 만들기 위해 만들어짐
#   *   소스 코드 (source code) : 프로그래밍 언어로 작성한 프로그램
#   *   코드 실행기 : 프로그래밍 언어는 컴퓨터가 이해할 수 없으므로 이를 이진 숫자로 변환해 주는 역할
#   *   개발 환경(IDE) : 프로그래밍을 할 수 있는 환경 -> VSCODE, 주피터 노트북, 파이참, COLAB
#   *   텍스트 에디터 : 프로그래밍 언어로 이루어진 코드를 작성하고 코드 실행기를 이용하여 텍스트 에디터가 작성한 코드를 실행
#   *   텍스트 에디터 : 파이썬 코드를 입력
#   *   파이썬 인터프리트 : 파이썬 코드를 실행

# %% [markdown]
# *   개발 전용 폰트 설치
#   *   D2Coding : https://github.com/naver/d2codingfont
#   *   설치 후 크롬에서 설정메뉴 -> 모양 -> 글꼴 맞춤설정에서 글꼴을 D2Coding 으로 설정

# %% [markdown]
# *   파이썬 기본 용어
#   *   표현식 (expression) : 파이썬에서 어떠한 값을 만들어내는 간단한 코드를 의미하며, 여기서 값이란 숫자 수식, 문자열 등이 될 수 있음
#   *   문장 (statement) : 표현식이 하나 이상 모일 경우, 그 자체로 어떠한 값을 만들 수 없으면 문장이 아님
#   *   프로그램 (program) : 문장이 모여서 형성
#   *   키워드 (keyword)
#       *   특별한 의미가 부여된 단어
#       *   파이썬에서 이미 특정 의미로 사용하기로 예약해 놓은 것
#       *   프로그래밍 언어에서 이름 정할 때 똑같이 사용할 수 없음
#       *   대소문자 구별

# %%
import keyword
print(keyword.kwlist)

# %% [markdown]
#   *   식별자
#     *   프로그래밍 언어에서 이름 붙일 때 사용하는 단어
#     *   변수 또는 함수 이름 등으로 사용
#     *   키워드 사용 불가
#     *   특수문자는 언더바(_)만 허용
#     *   숫자로 시작 불가
#     *   공백 포함 불가
#     *   알파벳 사용이 관례
#     *   의미 있는 단어로 할 것

# %% [markdown]
#   *   식별자 구분
#     *   대문자로 시작되는 경우 클래스
#     *   소문자로 시작하면 함수 또는 변수
#     *   뒤에 괄호 붙으면 함수
#     *   뒤에 괄호 없으면 변수

# %% [markdown]
# *   주석 (comment)
#   *   프로그램 진행에 영향 주지 않는 코드
#   *   프로그램 설명 위해 사용
#   *   (#)기호를 주석으로 처리하고자 하는 부분 앞에 붙임

# %% [markdown]
# *   연산자 : 스스로 값이 되는 것이 아닌 값과 값 사이에 무언가 기능 적용할 때 사용(+, -, *, /, %, //)
# *   리터럴 (literal) : 어떠한 값 자체
# *   print() 함수
#   *   출력 기능
#   *   출력하고 싶은 것들을 괄호 안에 나열

# %%
print("hello")
print("hello","python","world")

# %% [markdown]
# # 1. **자료형**

# %% [markdown]
# *   자료형 (data type)
#   *   자료를 기능과 역할에 따라 구분한 것
#   *   type() 함수로 확인( str : 문자열, int : 정수 , float : 실수 , bool : boolean )
#
#   *   문자열 (string) : 메일 제목, 메시지 내용 등
#   *   숫자 (number) : 물건의 가격, 학생의 성적 등
#   *   불 (boolean) : 친구의 로그인 상태 등
# *   자료를 알아야 하는 이유
#   *   자료를 자료형에 맞게 모으고 처리 과정을 거쳐 더 큰 자료형을 점차 만들어 나가면 프로그램이 완성됨
#   *   가장 기본 단위로서의 자료의 의미와 쓰임새를 아는 것은 매우 중요

# %% [markdown]
#   1)  문자열 : 큰 따옴표(") 혹은 작은 따옴표(') 이용
#   *  이스케이프 문자
#     *   역슬래시 기호와 함께 조합해서 사용하는 특수한 문자
#     *   \“ : 큰따옴표를 의미
#     *   \‘ : 작은따옴표를 의미
#     *   \n : 줄바꿈 의미
#     *   \t : 탭 의미

# %% [markdown]
#   *   문자열 연산자 : +(문자열 연결), *숫자(숫자만큼 문자열 반복)
#   *   문자열 선택 연산자(인덱싱) : [ ]
#     *   문자열 내부의 문자 하나를 선택
#     *   대괄호 안에 선택할 문자의 위치를 지정
#     *   인덱스 (index) : 제로 인덱스 (zero index) ~ 숫자를 0부터 셈
#     *   문자를 거꾸로 출력할 경우 음수값을 입력(예. 제일 마지막 문자의 경우 -1)

# %% [markdown]
#   *   문자열 범위 선택 연산자 (슬라이싱) : [:]
#     *   문자열의 특정 범위를 선택
#     *   대괄호 안에 범위 구분 위치를 콜론으로 구분
#     *   마지막 숫자 포함하지 않음

# %% [markdown]
#   *   len() 함수
#     * 문자열 길이 구할 때 사용
#     * 괄호 내부에 문자열 넣으면 문자열의 문자 개수 세어 줌
#     * 중첩된 구조의 함수는 괄호 안쪽부터 먼저 실행

# %% [markdown]
# 2) 숫자
#
# *   정수형
#   * 소수점이 없는 숫자
#   * 0, 1, 273, -52
# * 실수형
#   * 소수점이 있는 숫자
#   * 0.0, 52.273, -1.2
#   * 실수 (floating point, 부동 소수점)

# %% [markdown]
# *   사칙 연산자 : +, -, *, /
#   * 덧셈, 뺄셈, 곱셈, 나눗셈
# *   정수 나누기 연산자: //
#   * 숫자를 나누고 소수점 이하 자릿수 삭제한 후 정수 부분만 남김
# * 나머지 연산자 : %
#   * A를 B로 나누었을 때의 나머지를 구함
# * 제곱 연산자 : **
#   * 숫자를 제곱함

# %% [markdown]
# * 우선순위
#   * 파이썬의 수식은 연산자 간 우선순위에 따라 계산됨
#   * 곱셈과 나눗셈이 덧셈과 뺄셈보다 우선
#   * 괄호 활용하여 연산의 우선순위 조정

# %% [markdown]
# 3) 변수와 입력
#   * 변수
#     * 값을 저장할 때 사용하는 식별자
#     * 숫자뿐만 아니라 모든 자료형을 저장할 수 있음

# %% [markdown]
#   * 변수의 활용
#     * 변수를 선언하는 방법 : 변수를 생성
#     * 변수에 값을 할당하는 방법 : 변수에 값을 넣음(=연산자 이용)
#     * 변수를 참조하는 방법 : 변수를 이용하여 연산식 작성

# %%
# 원의 둘레와 넓이 구하기

# %% [markdown]
#   * 복합 대입 연산자
#     * 기본 대입 연산자(=)와 함께 사용해 구성

# %% [markdown]
#   * 사용자 입력 : input() 함수
#     * 명령 프롬프트에서 사용자로부터 데이터 입력받을 때 사용

# %%
input('인사말을 입력하세요')

# %% [markdown]
#   * 캐스트 (cast) : input() 함수의 입력 자료형은 항상 문자열이므로 입력받은 문자열을 숫자 연산에 활용하기 위해 숫자로 변환
#   * int() 함수 : 숫자형식의 문자열을 int 자료형으로 변환.
#   * float() 함수 : 숫자형식의 문자열을 float 자료형으로 변환
#   * str() 함수 : 숫자를 문자열로 변환

# %% [markdown]
#   * format() 함수
#     * 중괄호 포함한 문자열 뒤에 마침표 찍고 format() 함수 사용하되, 중괄호 개수와 format 함수 안 매개변수의 개수는 반드시 같아야 함
#     * 문자열의 중괄호 기호가 format() 함수 괄호 안의 매개변수로 차례로 대치되면서 숫자가 문자열이 됨

# %%
"{}".format(10)
"{} {}".format(10,20)
"{} {} {} {}".format(100,200,300,400)

# %% [markdown]
#   * format() 함수 형식지정
#     * {:05d} , {:15.3f}

# %% [markdown]
#   * upper() 함수 : 문자의 알파벳을 대문자로 바꿈
#   * lower() 함수 : 문자의 알파벳을 소문자로 바꿈
#   * strip() 함수 : 문자열 양옆의 공백을 제거
#   * lstrip() 함수 : 왼쪽의 공백을 제거
#   * rstrip() 함수 : 오른쪽의 공백을 제거

# %% [markdown]
#   * 문자열의 구성 파악
#     * isalnum(), isalpha(), isdecimal(), isdigit(), isspace(), islower(), isupper()

# %% [markdown]
#   * 불(boolean) : 출력이 True 혹은 False 로 나오는 것

# %% [markdown]
#   * 문자열 찾기
#     * find() : 왼쪽부터 찾아서 처음 등장하는 위치 찾음
#     * rfind() : 오른쪽부터 찾아서 처음 등장하는 위치 찾음

# %% [markdown]
#   * in 연산자
#     * 문자열 내부에 어떤 문자열이 있는지 확인할 때 사용
#     * 결과는 True(맞다), False(아니다)로 출력
#   * split() 함수
#     * 문자열을 특정한 문자로 자름
#     * 실행 결과는 리스트 (list)로 출력

# %% [markdown]
# # **2. 조건문과 반복문**

# %% [markdown]
# 1) 불 자료형과 if 조건문
#   * Boolean
#     * 불린 / 불리언 / 불
#     * True와 False 값만 가질 수 있음
#     * 비교 연산자를 통해 만들 수 있음

# %% [markdown]
#   * not 연산자 : 단항 연산자, 참과 거짓 반대로 바꿈
#   * and(&), or(|) 연산자

# %% [markdown]
#   * if 조건문 : 조건에 따라 코드 실행하거나 실행하지 않게 할 때 사용하는 구문

# %%
number=input("정수 입력> :")
number=int(number)

if number>0:
  print("양수 입니다.")
if number<0:
  print("음수 입니다.")
if number==0:
  print("0 입니다.")

# %% [markdown]
#   * 짝수와 홀수를 구분하는 세 가지 방법

# %%
# 끝자리로 짝수와 홀수 구분

# %%
# in 연산자를 활용하여 짝수와 홀수 구분

# %%
# 나머지 값을 구하여 짝수와 홀수 구분

# %% [markdown]
#   * else 구문
#     * if 조건문 뒤에 사용하며, if 조건문의 조건이 거짓을 때 실행되는 부분
#     * 조건문이 오로지 두 가지로만 구분될 때 if else 구문을 사용하면 조건 비교를 단 한번만 하므로 이전의 코드보다 두 배 효율적

# %%
# 나머지 값을 구하여 짝수와 홀수 구분

# %% [markdown]
#   * elif 구문
#     * 세 개 이상의 조건을 연결해서 사용
#     * if 조건문과 else 구문 사이에 입력

# %%
# 점수에 따른 등급 매기기

# %% [markdown]
#   * 빈 컨테이너
#     * if 조건문의 매개변수에 불 아닌 다른 값이 올 때 자동으로 불로 변환
#     * 이 때 False로 변환되는 값: None, 0.0, 빈 문자열, 빈 바이트열, 빈 리스트

# %% [markdown]
#   * pass 키워드 : 나중에 구현하고자 구문을 비워 두는 경우

# %% [markdown]
# 2) 리스트와 반복문
#   * 리스트 (list)
#     * 여러 가지 자료를 저장할 수 있는 자료
#     * 자료들을 모아서 사용할 수 있게 해 줌
#     * 대괄호([ ]) 내부에 자료들 넣어 선언

# %% [markdown]
#   * 요소 (element) : 리스트의 대괄호 내부에 넣는 자료
#   * 인덱싱 : 리스트 내부의 요소 각각 사용하려면 리스트 이름 바로 뒤에 대괄호 입력 후 자료의 위치 나타내는 숫자 입력
#   * 리스트 특정 요소를 변경할 수 있음
#   * 대괄호 안에 음수 넣어 뒤에서부터 요소 선택하기
#   * 리스트 접근 연산자를 이중으로 사용할 수 있음
#   * 리스트 연산자: 연결(+), 반복(*), len()

# %% [markdown]
#   * append() 함수 : 리스트 뒤에 요소를 추가
#   * insert() 함수 : 리스트 중간에 요소를 추가
#   * extend() 함수 : 원래 리스트 뒤에 새로운 리스트의 요소 모두 추가하며, 매개변수로 리스트 입력

# %% [markdown]
#   * 인덱스로 제거하기: del 키워드, pop() 함수
#     * pop() 함수의 경우 인덱스 없으면, 제일 마지막 원소 삭제

# %%
# del 리스트명[인덱스], 리스트명.pop(인덱스)

# %% [markdown]
#   * 값으로 제거하기: remove() 함수
#     * 특정 값을 지정하여 제거(제일 처음 찾은 값만 삭제, 모두 삭제하려면 반복문 사용하면 됨)

# %% [markdown]
#   * 모두 제거하기 : clear() 함수
#     * 리스트 내부의 요소를 모두 제거
#   * in 연산자 : 특정 값이 리스트 내부에 있는지 확인
#   * not in 연산자 : 리스트 내부에 해당 값이 없는지 확인

# %% [markdown]
#   * for 반복문
#     * 문자열, 리스트, 딕셔너리 등과 조합하여 for 반복문을 사용

# %%
array=[273, 32, 50, 102, 22]
for element in array:
  print(element)

# %%
# 1부터 100까지 합계값 구하기

# %%
# input() 함수를 통해 입력된 값까지 합계값 구하기

# %% [markdown]
# 3) 딕셔너리와 반복문
#   * 딕셔너리 (dictionary) : 키를 기반으로 값을 저장하는 것
#   * 딕셔너리 선언 : 중괄호로 선언하며 ‘키: 값’ 형태를 쉼표로 연결해서 만듦

# %% [markdown]
#   * 특정 키 값만 따로 출력하기
#     * 딕셔너리 뒤에 대괄호 입력하고 그 내부에 키 입력

# %% [markdown]
#   * 딕셔너리에 값 추가할 때는 키를 기반으로 값 입력
#   * 딕셔너리에 이미 존재하는 키 지정하고 값 넣으면 기존 값을 대치

# %% [markdown]
#   * 딕셔너리 요소의 제거 : del 키워드

# %% [markdown]
#   * 딕셔너리 내부에 키가 있는지 확인하기
#     * in 키워드 : 사용자로부터 접근하고자 하는 키 입력 받은 후 존재하는 경우에만
#      접근하여 값을 출력

# %% [markdown]
#   * for 반복문과 딕셔너리의 조합

# %% [markdown]
#   * 범위 (range) : 특정 횟수만큼 반복해서 돌리고 싶을 때 for 반복문과 조합하여 사용
#     * 매개변수에 숫자를 한 개 넣는 방법 : 0부터 A-1까지의 정수로 범위 만듦
#     * 매개변수에 숫자를 두 개 넣는 방법 : A부터 B-1까지의 정수로 범위 만듦
#     * 매개변수에 숫자를 세 개 넣는 방법 : A부터 B-1까지의 정수로 범위 만들되 앞뒤의 숫자가 C만큼의 차이 가짐

# %% [markdown]
#   * for 반복문과 범위의 조합
#     * 몇 번 반복인지를 알아야 하는 경우

# %% [markdown]
#   * 역반복문
#     * 큰 숫자에서 작은 숫자로 반복문 적용
#     * range() 함수의 매개변수 세 개 사용하는 방법

# %% [markdown]
#   * while 반복문
#     * 리스트 또는 딕셔너리 내부의 요소를 특정 횟수만큼 반복

# %%
# 1부터 100까지 합계값 구하기

# %%
# input() 함수를 통해 입력된 값까지 합계값 구하기

# %% [markdown]
#   * 리스트 내부에서 해당하는 값을 여러 개 제거
#     * while 반복문의 조건을 ‘리스트 내부에 요소가 있는 동안’으로 지정

# %% [markdown]
#   * break 키워드 : 반복문 벗어날 때 사용하는 키워드
#   * continue 키워드 : 현재 반복을 생략하고 다음 반복으로 넘어감

# %% [markdown]
# 4) 문자열, 리스트, 딕셔너리와 관련된 기본 함수
#   * 파이썬만의 고유한 기능들
#     *    리스트에 적용할 수 있는 기본 함수 : min(), max(), sun()
#     * 현재 인덱스가 몇 번째인지 확인하기 : enumerate()
#     *    딕셔너리로 쉽게 반복문 작성하기 : item()
#     *    리스트 안에 for문 사용하기 : 리스트 내포

# %% [markdown]
#   * enumerate() 함수
#     * 리스트 요소 반복할 때 현재 인덱스가 몇 번째인지 확인

# %% [markdown]
#   * 딕셔너리와 items() 함수 함께 사용하면 키와 값을 조합하여 쉽게 반복문 작성할 수 있음

# %% [markdown]
#   * 리스트 내포
#     * 반복문 사용하여 리스트 재조합하는 경우(예. 반복문을 사용한 리스트 생성)

# %% [markdown]
# # **3. 함수**

# %% [markdown]
# * 함수와 관련된 기본 용어
#   * 함수를 호출 : 함수 사용
#   * 매개변수 : 함수 호출 시 괄호 내부에 넣는 여러 가지 자료
#   * 리턴값 : 함수를 호출하여 최종적으로 나오는 결과

# %%
def print_3_times():
  print("hello python world!!!")
  print("hello python world!!!")
  print("hello python world!!!")

# %% [markdown]
#   * 가변 매개변수
#     * 매개변수를 원하는 만큼 받을 수 있는 함수
#     * 가변 매개변수 뒤에는 일반 매개변수 올 수 없음
#     * 가변 매개변수는 하나만 사용할 수 있음

# %% [markdown]
#   * 기본 매개변수
#     * 매개변수 값 입력하지 않았을 경우 매개변수에 들어가는 기본값
#     * 기본 매개변수가 가변 매개변수보다 앞에 올 때 기본 매개변수의 의미가 사라짐
#     * 가변 매개변수가 기본 매개변수보다 앞에 올 때 가변 매개변수가 우선됨

# %% [markdown]
#   * 키워드 매개변수
#     * 매개변수 이름을 지정해서 입력하는 매개변수
#     * 기본 매개변수 중에서 필요한 값만 입력해서 사용

# %% [markdown]
#   * 리턴값 (return value) : 함수의 결과
#     * return 키워드 : 함수를 실행했던 위치로 돌아가게 함, 리턴 뒤에 자료 입력하면 자료 가지고 돌아감
#     * None : ‘없다’라는 의미

# %%
# 범위를 지정해 범위안의 모든 정수의 합계값을 구하는 함수

# %% [markdown]
#   * 재귀함수(recursive function) : 함수 내부에서 자기 자신을 호출하는 함수

# %%
# 팩토리얼 값을 구하는 반복문

# %%
# 팩토리얼 값을 구하는 재귀함수

# %%
# 피보나치 수열

# %% [markdown]
#   * 피보나치 수열을 구하는 재귀함수의 경우 엄청난 시간을 요함. 이를 해결하기위한 방법 필요
#   * 메모화
#     * 재귀 함수를 사용하면서 코드가 빠르게 실행되려면?
#     * 같은 값을 한 번만 계산하도록 코드를 수정

# %% [markdown]
#   * 메모 (memo)
#     * 딕셔너리를 사용해서 한 번 계산한 값을 저장
#     * 처리 수행하지 않고 메모된 값 돌려주면서 코드 속도 향상
#     * 재귀함수와 자주 함께 사용하는 기술

# %% [markdown]
#   * 튜플 (tuple)
#     * 함수와 함께 많이 사용되는 리스트와 비슷한 자료형으로, 한번 결정된 요소를 바꿀 수 없다는 점이 리스트와 다름
#
#   * 람다 (lambda)
#     * 매개변수로 함수를 전달하기 위해 함수 구문을 작성하는 것이 번거롭고 코드 낭비라 생각될 때 함수를 간단하고 쉽게 선언하는 방법

# %% [markdown]
#   * filter() 함수와 map() 함수
#     * 함수를 매개변수로 전달하는 대표적인 표준함수
#     * 매개변수에 들어오는 함수를 콜백함수라고 함

# %% [markdown]
#   * 파일처리
#     * 텍스트 파일의 처리
#     * 파일 열기 (open) - 파일 읽기 (read) - 파일 쓰기 (write)
#     * 파일 열고 닫기
#       * open() 함수
#       * closed() 함수

# %%
# 파일객체 = open("파일경로", "모드") , 모드는 w, a, r

# %% [markdown]
#   * with 키워드
#     * 조건문과 반복문 들어가다 보면 파일을 열고서 닫지 않는 실수 하는 경우 생길 수 있음
#     * with 구문 종료 시 파일을 자동으로 닫음
#   * 텍스트 읽기
#     * read() 함수
